# %%
# !pip install fastapi uvicorn[standard] python-multipart streamlit requests tensorflow opencv-python mediapipe numpy scipy pillow
# Out:
# Requirement already satisfied: fastapi in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (0.115.14)
# Requirement already satisfied: python-multipart in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (0.0.20)
# Requirement already satisfied: streamlit in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (1.45.1)
# Requirement already satisfied: requests in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (2.32.3)
# Requirement already satisfied: tensorflow in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (2.19.0)
# Requirement already satisfied: opencv-python in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (4.11.0.86)
# Requirement already satisfied: mediapipe in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (0.10.21)
# Requirement already satisfied: numpy in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (1.26.4)
# Requirement already satisfied: scipy in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (1.15.3)
# Requirement already satisfied: pillow in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (11.2.1)
# Requirement already satisfied: uvicorn[standard] in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (0.35.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from fastapi) (0.46.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from fastapi) (2.11.5)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from fastapi) (4.13.2)
# Requirement already satisfied: click>=7.0 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from uvicorn[standard]) (8.2.1)
# Requirement already satisfied: h11>=0.8 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from uvicorn[standard]) (0.16.0)
# Requirement already satisfied: colorama>=0.4 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from uvicorn[standard]) (0.4.6)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from uvicorn[standard]) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from uvicorn[standard]) (1.1.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from uvicorn[standard]) (6.0.2)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from uvicorn[standard]) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from uvicorn[standard]) (15.0.1)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from streamlit) (5.5.2)
# Requirement already satisfied: packaging<25,>=20 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from streamlit) (2.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from streamlit) (4.25.8)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from streamlit) (20.0.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from streamlit) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from streamlit) (6.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from requests) (2025.4.26)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: setuptools in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from tensorflow) (75.8.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from tensorflow) (1.74.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from tensorflow) (3.11.1)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from mediapipe) (25.3.0)
# Requirement already satisfied: jax in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from mediapipe) (0.7.1)
# Requirement already satisfied: jaxlib in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from mediapipe) (0.7.1)
# Requirement already satisfied: matplotlib in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from mediapipe) (3.10.3)
# Requirement already satisfied: opencv-contrib-python in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from mediapipe) (4.10.0.84)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from mediapipe) (0.5.2)
# Requirement already satisfied: sentencepiece in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from mediapipe) (0.2.1)
# Requirement already satisfied: jinja2 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from altair<6,>=4.0->streamlit) (1.42.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: rich in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from keras>=3.5.0->tensorflow) (0.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.4.1)
# Requirement already satisfied: CFFI>=1.0 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from starlette<0.47.0,>=0.40.0->fastapi) (4.9.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from matplotlib->mediapipe) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from matplotlib->mediapipe) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from matplotlib->mediapipe) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from matplotlib->mediapipe) (3.2.3)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi) (1.3.1)
# Requirement already satisfied: pycparser in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ramya\anaconda3\envs\llms\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
import numpy as np
import cv2
import mediapipe as mp
from PIL import Image
import io

# %%
def classify_species(image_bytes: bytes) -> dict:
    try:
        image = Image.open(io.BytesIO(image_bytes))
        width, height = image.size
        if width < height:
            species = "Gir Cow"
            confidence = np.random.uniform(0.90, 0.99)
        else:
            species = "Murrah Buffalo"
            confidence = np.random.uniform(0.88, 0.98)
        print(f"✅ Classifier simulation successful: Detected {species}")
        return {"species": species, "confidence": float(confidence)}
    except Exception as e:
        print(f"❌ Error in classifier: {e}")
        return { "species": "Error", "confidence": 0.0 }

# %%
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=False, model_complexity=1, min_detection_confidence=0.5)

def extract_keypoints_from_video(video_path: str) -> list:
    cap = cv2.VideoCapture(video_path)
    keypoints_data = []
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        results = pose.process(image)
        if results.pose_landmarks:
            frame_keypoints = {}
            for i, landmark in enumerate(results.pose_landmarks.landmark):
                if i in [23, 24, 25, 26, 27, 28]:
                    landmark_name = mp_pose.PoseLandmark(i).name
                    frame_keypoints[landmark_name] = {
                        "x": landmark.x,
                        "y": landmark.y,
                        "z": landmark.z,
                        "visibility": landmark.visibility
                    }
            if frame_keypoints:
                keypoints_data.append(frame_keypoints)
    cap.release()
    print(f"✅ Pose estimation successful: Extracted keypoints from {len(keypoints_data)} frames.")
    return keypoints_data

# %%
def calculate_mobility_score(keypoints_data: list) -> dict:
    if len(keypoints_data) < 15:
        return {"mobility_score": -1, "score_type": "Insufficient Video Length"}

    left_hip_y = [frame.get('LEFT_HIP', {}).get('y') for frame in keypoints_data]
    right_hip_y = [frame.get('RIGHT_HIP', {}).get('y') for frame in keypoints_data]
    left_hip_y = [y for y in left_hip_y if y is not None]
    right_hip_y = [y for y in right_hip_y if y is not None]

    if len(left_hip_y) < 10 or len(right_hip_y) < 10:
        return {"mobility_score": -1, "score_type": "Could Not Track Hips"}

    std_dev_left = np.std(left_hip_y)
    std_dev_right = np.std(right_hip_y)
    avg_bobbing_motion = (std_dev_left + std_dev_right) / 2

    if avg_bobbing_motion < 0.01:
        score = 0
        score_type = "Prime Mobility"
    elif avg_bobbing_motion < 0.025:
        score = 1
        score_type = "At-Risk"
    else:
        score = 2
        score_type = "Lame Mobility Detected"

    print(f"✅ Gait analysis successful: Score {score}, Motion value {avg_bobbing_motion:.4f}")
    return {"mobility_score": score, "score_type": score_type}

# %%
# Replace this path with your cow/buffalo video file
video_path = "sample_video.mp4"

# Step 1: classify using first frame
cap = cv2.VideoCapture(video_path)
ret, frame = cap.read()
cap.release()
if ret:
    _, buffer = cv2.imencode('.jpg', frame)
    first_frame_bytes = buffer.tobytes()
    classification_result = classify_species(first_frame_bytes)
else:
    classification_result = {"species": "Error", "confidence": 0.0}

# Step 2: extract keypoints
keypoints_data = extract_keypoints_from_video(video_path)

# Step 3: gait analysis
gait_result = calculate_mobility_score(keypoints_data)

# Final Results
print("\n=== FINAL RESULTS ===")
print("Classification:", classification_result)
print("Gait Analysis:", gait_result)
# Out:
# ✅ Pose estimation successful: Extracted keypoints from 0 frames.
#
# === FINAL RESULTS ===
# Classification: {'species': 'Error', 'confidence': 0.0}
# Gait Analysis: {'mobility_score': -1, 'score_type': 'Insufficient Video Length'}
